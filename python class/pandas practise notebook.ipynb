# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\User\Downloads\Customer-Churn-Records.csv")

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited', 'Complain',
#        'Satisfaction Score', 'Card Type', 'Point Earned'],
#       dtype='object')

# %%
# to rename a columns
df.rename(columns={'RowNumber': 'Row','CustomerId':'customerNO'}, inplace= True)

# %%
df
# Out:
#         Row  customerNO    Surname  CreditScore Geography  Gender  Age  \
# 0         1    15634602   Hargrave          619    France  Female   42
# 1         2    15647311       Hill          608     Spain  Female   41
# 2         3    15619304       Onio          502    France  Female   42
# 3         4    15701354       Boni          699    France  Female   39
# 4         5    15737888   Mitchell          850     Spain  Female   43
# ...     ...         ...        ...          ...       ...     ...  ...
# 9995   9996    15606229   Obijiaku          771    France    Male   39
# 9996   9997    15569892  Johnstone          516    France    Male   35
# 9997   9998    15584532        Liu          709    France  Female   36
# 9998   9999    15682355  Sabbatini          772   Germany    Male   42
# 9999  10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
# to dropping of column
df.drop(['Surname','Age'],axis =1, inplace=True)

# %%
df
# Out:
#         Row  customerNO  CreditScore Geography  Gender  Tenure    Balance  \
# 0         1    15634602          619    France  Female       2       0.00
# 1         2    15647311          608     Spain  Female       1   83807.86
# 2         3    15619304          502    France  Female       8  159660.80
# 3         4    15701354          699    France  Female       1       0.00
# 4         5    15737888          850     Spain  Female       2  125510.82
# ...     ...         ...          ...       ...     ...     ...        ...
# 9995   9996    15606229          771    France    Male       5       0.00
# 9996   9997    15569892          516    France    Male      10   57369.61
# 9997   9998    15584532          709    France  Female       7       0.00
# 9998   9999    15682355          772   Germany    Male       3   75075.31
# 9999  10000    15628319          792    France  Female       4  130142.79
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# ...

# %%
df.iloc[0:16]
# Out:
#     Row  customerNO  CreditScore Geography  Gender  Tenure    Balance  \
# 0     1    15634602          619    France  Female       2       0.00
# 1     2    15647311          608     Spain  Female       1   83807.86
# 2     3    15619304          502    France  Female       8  159660.80
# 3     4    15701354          699    France  Female       1       0.00
# 4     5    15737888          850     Spain  Female       2  125510.82
# 5     6    15574012          645     Spain    Male       8  113755.78
# 6     7    15592531          822    France    Male       7       0.00
# 7     8    15656148          376   Germany  Female       4  115046.74
# 8     9    15792365          501    France    Male       4  142051.07
# 9    10    15592389          684    France    Male       2  134603.88
# 10   11    15767821          528    France    Male       6  102016.72
# 11   12    15737173          497     Spain    Male       3       0.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Row                 10000 non-null  int64
#  1   customerNO          10000 non-null  int64
#  2   CreditScore         10000 non-null  int64
#  3   Geography           10000 non-null  object
#  4   Gender              10000 non-null  object
#  5   Tenure              10000 non-null  int64
#  6   Balance             10000 non-null  float64
#  7   NumOfProducts       10000 non-null  int64
#  8   HasCrCard           10000 non-null  int64
#  9   IsActiveMember      10000 non-null  int64
#  10  EstimatedSalary     10000 non-null  float64
#  11  Exited              10000 non-null  int64
#  12  Complain            10000 non-null  int64
#  13  Satisfaction Score  10000 non-null  int64
#  14  Card Type           10000 non-null  object
# ...

# %%
df.describe()
# Out:
#                Row    customerNO   CreditScore        Tenure        Balance  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000   10000.000000
# mean    5000.50000  1.569094e+07    650.528800      5.012800   76485.889288
# std     2886.89568  7.193619e+04     96.653299      2.892174   62397.405202
# min        1.00000  1.556570e+07    350.000000      0.000000       0.000000
# 25%     2500.75000  1.562853e+07    584.000000      3.000000       0.000000
# 50%     5000.50000  1.569074e+07    652.000000      5.000000   97198.540000
# 75%     7500.25000  1.575323e+07    718.000000      7.000000  127644.240000
# max    10000.00000  1.581569e+07    850.000000     10.000000  250898.090000
#
#        NumOfProducts    HasCrCard  IsActiveMember  EstimatedSalary  \
# count   10000.000000  10000.00000    10000.000000     10000.000000
# mean        1.530200      0.70550        0.515100    100090.239881
# std         0.581654      0.45584        0.499797     57510.492818
# ...
