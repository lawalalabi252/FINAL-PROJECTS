# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('irisnew.csv')

# %%
df
# Out:
#      Unnamed: 0.1  Unnamed: 0  sepal_length  sepal_width  petal_length  \
# 0               0           0           5.1          3.5           1.4
# 1               1           1           4.9          3.0           1.4
# 2               2           2           4.7          3.2           1.3
# 3               3           3           4.6          3.1           1.5
# 4               4           4           5.0          3.6           1.4
# ..            ...         ...           ...          ...           ...
# 145           145         145           6.7          3.0           5.2
# 146           146         146           6.3          2.5           5.0
# 147           147         147           6.5          3.0           5.2
# 148           148         148           6.2          3.4           5.4
# 149           149         149           5.9          3.0           5.1
#
#      petal_width         species
# 0            0.2     Iris-setosa
# 1            0.2     Iris-setosa
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'sepal_length', 'sepal_width',
#        'petal_length', 'petal_width', 'species'],
#       dtype='object')

# %%
# renaming a columns
df.rename(columns={'Unnamed: 0.1': 'index1', 'Unnamed: 0': 'index2'}, inplace= True)

# %%
df
# Out:
#      index1  index2  sepal_length  sepal_width  petal_length  petal_width  \
# 0         0       0           5.1          3.5           1.4          0.2
# 1         1       1           4.9          3.0           1.4          0.2
# 2         2       2           4.7          3.2           1.3          0.2
# 3         3       3           4.6          3.1           1.5          0.2
# 4         4       4           5.0          3.6           1.4          0.2
# ..      ...     ...           ...          ...           ...          ...
# 145     145     145           6.7          3.0           5.2          2.3
# 146     146     146           6.3          2.5           5.0          1.9
# 147     147     147           6.5          3.0           5.2          2.0
# 148     148     148           6.2          3.4           5.4          2.3
# 149     149     149           5.9          3.0           5.1          1.8
#
#             species
# 0       Iris-setosa
# 1       Iris-setosa
# ...

# %%
# dropping columns
df.drop(['index1', 'index2'], axis=1, inplace= True)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.species.value_counts()
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
# creating new columns
df['new'] = df['sepal_length'] * 3

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#       new
# 0    15.3
# 1    14.7
# 2    14.1
# 3    13.8
# 4    15.0
# ...

# %%
# use normal function to create new columns
def create(x):
    if x == 'Iris-setosa':
        x = 1
    elif x == 'Iris-virginica':
        x = 2
    return x


df['new_column'] = df['species'].apply(create)

# %%
df.sample()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species  \
# 130           7.4          2.8           6.1          1.9  Iris-virginica
#
#       new new_column
# 130  22.2          2

# %%
# use lambda function to create new columns
df['column2'] = df['species'].apply(lambda x: 1 if x=='Iris-setosa' else 2 if x == 'Iris versicolor' else 3)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#       new new_column  column2
# 0    15.3          1        1
# ...

# %%
df['new'] = df['new'].apply(lambda x: x * 20)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#        new new_column  column2
# 0    306.0          1        1
# ...

# %%
# to convert datatypes
df['column2'] = df['column2'].astype('float')

# %%
df['new'] = df['new'] + df['column2']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
#  5   new           150 non-null    float64
#  6   new_column    150 non-null    object
#  7   column2       150 non-null    float64
# dtypes: float64(6), object(2)
# memory usage: 9.5+ KB

# %%
# drawing graphs
df.boxplot('sepal_length')
# Out:
# <Axes: >

# %%
df.drop_duplicates()
df.dropna()
df.copy()
df.fillna(0)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#        new new_column  column2
# 0    307.0          1      1.0
# ...

# %%
ser = df['sepal_length'].get(5)

# %%
df.groupby(['species'])['petal_length'].mean().sort_index(ascending=False)
# Out:
# species
# Iris-virginica     5.552
# Iris-versicolor    4.260
# Iris-setosa        1.464
# Name: petal_length, dtype: float64

# %%
if 5>3 == True: print('Yes')
