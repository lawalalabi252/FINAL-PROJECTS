# %%
what's data preprocessing ?
     data preprocessing is the concept of changing the raw data set into a clean data set.
the data set is preprocessed in order to check missing values


four types of data pre-processing
1.data clean
2.data integration
3.data reduction
4.data transformation


data processing ? refer to the entire processs of collecting transforming(i.e cleaning or putting the data into a usable)
and classifying data
    
    
    libraries involved in data processing 
    
1.numpy
2.pandas
3.scikit-learn
4.matplotlib
5.scipy
6.seaborn
7.plotly
8.pytourch
9.nltk
10.bokeh
11.deep learning 
12.open CV

According to the research pandas is the most widely used.



         things i can do in data processing 
1.data collection:sources of raw data; such as emails, apps, websites, social media and stock market and financial data.
    
2.data preparation:involves tidying a raw dataset and introducing structure.
    
3.data input:this is the process of converting raw data into a machine -readable format.

4.data processing:once the data have been input into the appropiate system they can be processed using a variety of different techniques.
5.data output:once the dataset have been processed the results can finally be delivered to the end-user
6.data storage:the final step is the data storage. this is where the otput is either loaded into another system for future use.
          
        
        types of data processing 
        
1.batch processing:is the computer processes raw data in multiple small batches.it is commonly used for large ,homogeous dataset
    
2.real-time processing:is when data is processed immediately after being input into the cpu.
    
3.online pocessing: is another form of real-time processing which as the same suggests, focuses specfically on online task.
    
4.distributed processing:is when processing tasks are shared across a network of different computers.
    
    
     importance of data processing 

1.more effective storage
2.eaiser to produce report 
3.improved productivity
4.it is more Accurate.
